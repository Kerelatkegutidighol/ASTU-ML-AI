# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("PCA_practice_dataset.csv")

# %%
X = df.to_numpy()
X.shape
# Out:
# (8041, 35)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
covariance_matrix = np.cov(X.T)

# %%
eig_val, eig_vec = np.linalg.eig(covariance_matrix)

# %%
sort_idx = np.argsort(eig_val)
sort_idx = sort_idx[::-1]

# %%
eig_val_sum = np.sum(eig_val)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.90*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 3

# %%
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

# %%
projection_matrix = (eig_vec.T[:][:3]).T
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.91*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 3

# %%
projection_matrix = (eig_vec.T[:][:3]).T  
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.92*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding:  {}".format(i))
# Out:
# No. of components retained due to thresholding:  4

# %%
projection_matrix = (eig_vec.T[:][:4]).T 
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.93*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 4

# %%
projection_matrix = (eig_vec.T[:][:4]).T 
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.94*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding:  {}".format(i))
# Out:
# No. of components retained due to thresholding:  5

# %%
projection_matrix = (eig_vec.T[:][:5]).T 
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.95*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 5

# %%
projection_matrix = (eig_vec.T[:][:5]).T 
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.96*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 6

# %%
projection_matrix = (eig_vec.T[:][:6]).T 
X_pca = X.dot(projection_matrix)

# %%
temp_sum = 0
principal_eig_vec = []
principal_eig_val = []
i=0
while(temp_sum<0.97*eig_val_sum):
    principal_eig_vec.append(eig_vec[sort_idx[i]])
    principal_eig_val.append(eig_val[sort_idx[i]])
    temp_sum += eig_val[sort_idx[i]]
    i += 1
    
fig, ax = plt.subplots()

ax.plot(principal_eig_val)
ax.set_title("Eigen-values corresponding to the principal components")

plt.tight_layout()

print("No. of components retained due to thresholding: {}".format(i))
# Out:
# No. of components retained due to thresholding: 7
